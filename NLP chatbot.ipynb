# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer
import tensorflow as tensorF
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import string

# Define 'lm' as a WordNetLemmatizer object
lm = WordNetLemmatizer()
data = {
    "intents": [
        {
            "tag": "increase productivity",
            "patterns": ["How can we increase productivity?", "Ways to improve efficiency?"],
            "responses": ["Increasing productivity involves optimizing processes, adopting new technologies, and providing training."],
        },
        {
            "tag": "interdepartment coordination",
            "patterns": ["How can we enhance interdepartment coordination?", "Improving collaboration between departments?"],
            "responses": ["Interdepartment coordination can be improved by using communication tools, setting clear goals, and fostering teamwork."],
        },
        {
            "tag": "job satisfaction",
            "patterns": ["How to enhance job satisfaction?", "Increasing employee happiness?"],
            "responses": ["Job satisfaction can be improved by providing a positive work environment, recognition, and opportunities for growth."],
        },
        {
            "tag": "equipment status",
            "patterns": ["What is the status of excavator?", "Is the crusher running?", "Check the conveyor belt."],
            "responses": ["The excavator is operational.", "The crusher is currently offline.", "The conveyor belt is functioning."],
        },
        {
            "tag": "safety",
            "patterns": ["What are the safety procedures?", "How to report a safety incident?"],
            "responses": ["Safety procedures include wearing protective gear. To report an incident, contact the safety department."],
        },
        {
            "tag": "geological data",
            "patterns": ["Tell me about the geological data.", "Where is the mining site located?"],
            "responses": ["The mining site is in XYZ region. Geological data shows rich mineral deposits in this area."],
        },
        {
            "tag": "resource management",
            "patterns": ["Optimize resource allocation.", "Order more drilling equipment."],
            "responses": ["Resource allocation has been optimized. New drilling equipment has been ordered."],
        },
    ]
}

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import numpy as np

iShape = (len(x[0]),)
oShape = len(y[0])

# Define the model
ourNewModel = Sequential()

# Add layers to the model
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
ourNewModel.add(Dropout(0.5))
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation="softmax"))

# Create the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

# Compile the model
ourNewModel.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

# Output the model summary
print(ourNewModel.summary())

# Train the model
ourNewModel.fit(x, y, epochs=20, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 128)               7040
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 7)                 455
#
# ...
# Total params: 15751 (61.53 KB)
# Trainable params: 15751 (61.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 1/1 [==============================] - 1s 772ms/step - loss: 1.9906 - accuracy: 0.2667
# Epoch 2/20
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9066 - accuracy: 0.2000
# Epoch 3/20
# 1/1 [==============================] - 0s 13ms/step - loss: 1.6989 - accuracy: 0.3333
# Epoch 4/20
# ...

# %%
# Adapted function for retrieving responses
def getRes(firstlist, fJson):
    tag = firstlist[0]
    listOfIntents = fJson["intents"]
    for i in listOfIntents:
        if i["tag"] == tag:
            ourResult = random.choice(i["responses"])
            break
    return ourResult

# %%
def wordBag(text, vocab):
    newtkns = ourText(text)
    bagOwords = [0] * len(vocab)
    for w in newtkns:
        for idx, word in enumerate(vocab):
            if word == w:
                bagOwords[idx] = 1
    return num.array(bagOwords)

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, data)
    print(ourResult)
# Out:
# increase productivity
# 1/1 [==============================] - 0s 85ms/step
# Increasing productivity involves optimizing processes, adopting new technologies, and providing training.
# safety
# 1/1 [==============================] - 0s 23ms/step
# Safety procedures include wearing protective gear. To report an incident, contact the safety department.
# resource management
# 1/1 [==============================] - 0s 26ms/step
# Resource allocation has been optimized. New drilling equipment has been ordered.
# geological data
# 1/1 [==============================] - 0s 27ms/step
# The mining site is in XYZ region. Geological data shows rich mineral deposits in this area.
